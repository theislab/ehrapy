# %%
import matplotlib.pyplot as plt

import ehrapy as ep

# %%
# %load_ext autoreload
# %autoreload 2

# %%
current_notebook_dir = %pwd

_TEST_IMAGE_PATH = f"{current_notebook_dir}/../plot/_images"

adata = ep.dt.mimic_2(encoded=False)

# %%
plot = ep.pl.missing_values_barplot(adata, filter="bottom", max_cols=15, max_percentage=0.999)
fig = plot.figure
# subplot adjust is needed to enforce precise plot position here and in the test
fig.subplots_adjust(left=0.1, right=0.95, top=0.9, bottom=0.15)
plt.gcf().savefig(f"{_TEST_IMAGE_PATH}/missing_values_barplot_expected.png", dpi=80)
